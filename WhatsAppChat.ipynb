# %%
import re
import pandas as pd

# %%
f=open('WhatsApp Chat with AB JO H YAHI HE😂.txt','r',encoding='utf-8')

# %%
data=f.read()
print(type(data))
# Out:
# <class 'str'>

# %%
print(data)
# Out:
# 09/07/22, 9:10 am - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 08/02/22, 10:34 am - Kaustubh Aditya Sharma created group "AB JO H YAHI HE😂"
# 08/02/22, 10:34 am - You were added
# 11/07/22, 9:43 am - +91 97558 83794 left
# 12/07/22, 4:42 pm - Your security code with ~ Never Give Up changed. Tap to learn more.
# 13/07/22, 11:21 am - Your security code with Harsh Clg changed. Tap to learn more.
# 16/07/22, 8:26 am - Your security code with +91 74770 94006 changed. Tap to learn more.
# 18/07/22, 12:58 pm - Sujal Maurya: Hod sir ki email id hain
# 18/07/22, 1:00 pm - Kaustubh Aditya Sharma: Arry kya Hua balak
# 18/07/22, 1:18 pm - Sujal Maurya: Kaam hain nalayak
# 18/07/22, 1:22 pm - Kaustubh Aditya Sharma: Hmm HOD sir bhi yahi bolenge😂😂
# 18/07/22, 1:22 pm - Kaustubh Aditya Sharma: Aapse
# 18/07/22, 1:22 pm - Kaustubh Aditya Sharma: Ya bolenge kyu bol toh chuke he na 2-3 baar😂
# ...

# %%
pattern='\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s(?:am|pm)\s-\s'
# Define the pattern to match timestamps and messages
# pattern = r'\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s(?:am|pm)\s-\s(.*?)\n'
# Extract dates and messages separately
# matches = re.findall(pattern, data)

# %%
dates=re.findall(pattern,data)
dates
# Out:
# ['09/07/22, 9:10\u202fam - ',
#  '08/02/22, 10:34\u202fam - ',
#  '08/02/22, 10:34\u202fam - ',
#  '11/07/22, 9:43\u202fam - ',
#  '12/07/22, 4:42\u202fpm - ',
#  '13/07/22, 11:21\u202fam - ',
#  '16/07/22, 8:26\u202fam - ',
#  '18/07/22, 12:58\u202fpm - ',
#  '18/07/22, 1:00\u202fpm - ',
#  '18/07/22, 1:18\u202fpm - ',
#  '18/07/22, 1:22\u202fpm - ',
#  '18/07/22, 1:22\u202fpm - ',
#  '18/07/22, 1:22\u202fpm - ',
#  '18/07/22, 8:56\u202fpm - ',
#  '20/07/22, 7:36\u202fpm - ',
#  '20/07/22, 7:37\u202fpm - ',
#  '20/07/22, 8:42\u202fpm - ',
#  '20/07/22, 9:44\u202fpm - ',
#  '22/07/22, 11:58\u202fam - ',
#  '22/07/22, 5:04\u202fpm - ',
#  '22/07/22, 5:04\u202fpm - ',
#  '22/07/22, 5:04\u202fpm - ',
#  '23/07/22, 5:31\u202fpm - ',
#  '29/07/22, 4:14\u202fam - ',
#  '01/08/22, 1:57\u202fpm - ',
#  '02/08/22, 9:54\u202fam - ',
#  '02/08/22, 6:59\u202fpm - ',
#  '02/08/22, 9:48\u202fpm - ',
#  '05/08/22, 4:52\u202fpm - ',
#  '06/08/22, 5:45\u202fpm - ',
#  '07/08/22, 11:27\u202fam - ',
# ...

# %%
messages=re.split(pattern,data)[1:]
messages
# Out:
# ['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#  'Kaustubh Aditya Sharma created group "AB JO H YAHI HE😂"\n',
#  'You were added\n',
#  '+91 97558 83794 left\n',
#  'Your security code with ~\u202fNever Give Up changed. Tap to learn more.\n',
#  'Your security code with Harsh Clg changed. Tap to learn more.\n',
#  'Your security code with +91 74770 94006 changed. Tap to learn more.\n',
#  'Sujal Maurya: Hod sir ki email id hain\n',
#  'Kaustubh Aditya Sharma: Arry kya Hua balak\n',
#  'Sujal Maurya: Kaam hain nalayak\n',
#  'Kaustubh Aditya Sharma: Hmm HOD sir bhi yahi bolenge😂😂\n',
#  'Kaustubh Aditya Sharma: Aapse\n',
#  'Kaustubh Aditya Sharma: Ya bolenge kyu bol toh chuke he na 2-3 baar😂\n',
# ...

# %%
dates=re.findall(pattern,data)
dates
# Out:
# ['09/07/22, 9:10\u202fam - ',
#  '08/02/22, 10:34\u202fam - ',
#  '08/02/22, 10:34\u202fam - ',
#  '11/07/22, 9:43\u202fam - ',
#  '12/07/22, 4:42\u202fpm - ',
#  '13/07/22, 11:21\u202fam - ',
#  '16/07/22, 8:26\u202fam - ',
#  '18/07/22, 12:58\u202fpm - ',
#  '18/07/22, 1:00\u202fpm - ',
#  '18/07/22, 1:18\u202fpm - ',
#  '18/07/22, 1:22\u202fpm - ',
#  '18/07/22, 1:22\u202fpm - ',
#  '18/07/22, 1:22\u202fpm - ',
#  '18/07/22, 8:56\u202fpm - ',
#  '20/07/22, 7:36\u202fpm - ',
#  '20/07/22, 7:37\u202fpm - ',
#  '20/07/22, 8:42\u202fpm - ',
#  '20/07/22, 9:44\u202fpm - ',
#  '22/07/22, 11:58\u202fam - ',
#  '22/07/22, 5:04\u202fpm - ',
#  '22/07/22, 5:04\u202fpm - ',
#  '22/07/22, 5:04\u202fpm - ',
#  '23/07/22, 5:31\u202fpm - ',
#  '29/07/22, 4:14\u202fam - ',
#  '01/08/22, 1:57\u202fpm - ',
#  '02/08/22, 9:54\u202fam - ',
#  '02/08/22, 6:59\u202fpm - ',
#  '02/08/22, 9:48\u202fpm - ',
#  '05/08/22, 4:52\u202fpm - ',
#  '06/08/22, 5:45\u202fpm - ',
#  '07/08/22, 11:27\u202fam - ',
# ...

# %%
puj=[1,2,3,"viv"]
puj
# Out:
# [1, 2, 3, 'viv']

# %%
import pandas as pd

# Your code to extract messages and dates

df = pd.DataFrame({'user-message': messages, 'message-date': dates})
df['message-date'] = pd.to_datetime(df['message-date'], format='%d/%m/%y, %I:%M\u202f%p - ')
df.rename(columns={'message-date': 'date'}, inplace=True)
df.head(10)
# Out:
#                                         user-message                date
# 0  Messages and calls are end-to-end encrypted. N... 2022-07-09 09:10:00
# 1  Kaustubh Aditya Sharma created group "AB JO H ... 2022-02-08 10:34:00
# 2                                   You were added\n 2022-02-08 10:34:00
# 3                             +91 97558 83794 left\n 2022-07-11 09:43:00
# 4  Your security code with ~ Never Give Up change... 2022-07-12 16:42:00
# 5  Your security code with Harsh Clg changed. Tap... 2022-07-13 11:21:00
# 6  Your security code with +91 74770 94006 change... 2022-07-16 08:26:00
# 7           Sujal Maurya: Hod sir ki email id hain\n 2022-07-18 12:58:00
# 8       Kaustubh Aditya Sharma: Arry kya Hua balak\n 2022-07-18 13:00:00
# 9                  Sujal Maurya: Kaam hain nalayak\n 2022-07-18 13:18:00

# %%
df.shape
# Out:
# (1962, 2)

# %%
users = []
messages = []

for message in df['user-message']:
    entry = re.split('([\w\W]+?):\s', message)
    if entry[1:]:
        users.append(entry[1])
        messages.append(entry[0])
    else:
        users.append('group_notification')
        messages.append(entry[0])

df['user'] = users
df['message'] = messages
df.drop(columns=['user-message'], inplace=True)
df.sample()
# Out:
#                     date          user message
# 1269 2023-08-10 20:39:00  Garima Gupta

# %%
df.sample(10)
# Out:
#                     date             user message
# 305  2022-10-10 20:24:00  Abhishek Sharma
# 1428 2023-10-18 17:03:00   Deergha Tiwari
# 1736 2024-02-20 10:22:00  +91 96856 15029
# 50   2022-08-26 16:04:00             Roli
# 1392 2023-10-10 21:20:00      Devesh Shah
# 799  2023-01-10 18:38:00   Ꭺᴅᴀʀꜱʜ Kᴜsʜᴡᴀʜ
# 749  2023-01-01 00:14:00  +91 96856 15029
# 816  2023-01-11 20:57:00        Shruti CR
# 492  2022-10-26 20:09:00             Roli
# 489  2022-10-26 20:09:00             Roli

# %%
df['year']=df['date'].dt.year

# %%
df.head()
# Out:
#                  date                user  \
# 0 2022-07-09 09:10:00  group_notification
# 1 2022-02-08 10:34:00  group_notification
# 2 2022-02-08 10:34:00  group_notification
# 3 2022-07-11 09:43:00  group_notification
# 4 2022-07-12 16:42:00  group_notification
#
#                                              message  year
# 0  Messages and calls are end-to-end encrypted. N...  2022
# 1  Kaustubh Aditya Sharma created group "AB JO H ...  2022
# 2                                   You were added\n  2022
# 3                             +91 97558 83794 left\n  2022
# 4  Your security code with ~ Never Give Up change...  2022

# %%
df['month']=df['date'].dt.month_name()

# %%
df.head()
# Out:
#                  date                user  \
# 0 2022-07-09 09:10:00  group_notification
# 1 2022-02-08 10:34:00  group_notification
# 2 2022-02-08 10:34:00  group_notification
# 3 2022-07-11 09:43:00  group_notification
# 4 2022-07-12 16:42:00  group_notification
#
#                                              message  year     month
# 0  Messages and calls are end-to-end encrypted. N...  2022      July
# 1  Kaustubh Aditya Sharma created group "AB JO H ...  2022  February
# 2                                   You were added\n  2022  February
# 3                             +91 97558 83794 left\n  2022      July
# 4  Your security code with ~ Never Give Up change...  2022      July

# %%
df['day']=df['date'].dt.day

# %%
df['hour']=df['date'].dt.hour

# %%
df['minute']=df['date'].dt.minute

# %%
df.head()
# Out:
#                  date                user  \
# 0 2022-07-09 09:10:00  group_notification
# 1 2022-02-08 10:34:00  group_notification
# 2 2022-02-08 10:34:00  group_notification
# 3 2022-07-11 09:43:00  group_notification
# 4 2022-07-12 16:42:00  group_notification
#
#                                              message  year     month  day  \
# 0  Messages and calls are end-to-end encrypted. N...  2022      July    9
# 1  Kaustubh Aditya Sharma created group "AB JO H ...  2022  February    8
# 2                                   You were added\n  2022  February    8
# 3                             +91 97558 83794 left\n  2022      July   11
# 4  Your security code with ~ Never Give Up change...  2022      July   12
#
#    hour  minute
# 0     9      10
# 1    10      34
# 2    10      34
# 3     9      43
# 4    16      42

# %%
from urlextract import URLExtract
extractor=URLExtract()
urls=extractor.find_urls("Let's have URL www.gmail.com stackoverflow.com as an example www.google.com , http://facebook.com , ftp://url.in ")

# %%
urls
# Out:
# ['www.gmail.com',
#  'stackoverflow.com',
#  'www.google.com',
#  'http://facebook.com',
#  'ftp://url.in']

# %%
link=[]
for message in df['message']:
    link.extend(extractor.find_urls(message))

# %%
len(link)
# Out:
# 0

# %%
x=df['user'].value_counts().head()

# %%
import matplotlib.pyplot as plt

# %%
name=x.index
count=x.values

# %%
count
# Out:
# array([186, 156, 130, 115, 106], dtype=int64)

# %%
plt.bar(name,count)
plt.xticks(rotation='vertical')
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
py --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22268\773309365.py in <module>
# ----> 1 py --version
#
# NameError: name 'py' is not defined
